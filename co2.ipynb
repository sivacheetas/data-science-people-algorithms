# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data = pd.read_csv('Data/FuelConsumption.csv')
data
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
data.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
data.shape
# Out:
# (1067, 13)

# %%
data.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
# MODELYEAR                   1067 non-null int64
# MAKE                        1067 non-null object
# MODEL                       1067 non-null object
# VEHICLECLASS                1067 non-null object
# ENGINESIZE                  1067 non-null float64
# CYLINDERS                   1067 non-null int64
# TRANSMISSION                1067 non-null object
# FUELTYPE                    1067 non-null object
# FUELCONSUMPTION_CITY        1067 non-null float64
# FUELCONSUMPTION_HWY         1067 non-null float64
# FUELCONSUMPTION_COMB        1067 non-null float64
# FUELCONSUMPTION_COMB_MPG    1067 non-null int64
# CO2EMISSIONS                1067 non-null int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 87.6+ KB

# %%
data.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
data.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
x_data = data[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_CITY','FUELCONSUMPTION_HWY','FUELCONSUMPTION_COMB','FUELCONSUMPTION_COMB_MPG']]
x_data.head()
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0         2.0          4                   9.9                  6.7
# 1         2.4          4                  11.2                  7.7
# 2         1.5          4                   6.0                  5.8
# 3         3.5          6                  12.7                  9.1
# 4         3.5          6                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG
# 0                   8.5                        33
# 1                   9.6                        29
# 2                   5.9                        48
# 3                  11.1                        25
# 4                  10.6                        27

# %%
y_data = data[['CO2EMISSIONS']]
y_data.head()
# Out:
#    CO2EMISSIONS
# 0           196
# 1           221
# 2           136
# 3           255
# 4           244

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
fuel_model = model.fit(x_data,y_data)
fuel_model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
fuel_model.coef_
# Out:
# array([[  8.57767262,   7.698747  , -10.59262337,  -3.48918281,
#          17.75286099,  -3.86924281]])

# %%
fuel_model.intercept_
# Out:
# array([253.53120115])

# %%
fuel_model.rank_
# Out:
# 6

# %%
fuel_model.score(x_data,y_data)
# Out:
# 0.8892861092642407

# %%
from sklearn.model_selection import train_test_split

# %%
x_test,x_train,y_test,y_train = train_test_split(x_data,y_data,test_size=0.2)

# %%
x_train.shape
# Out:
# (214, 6)

# %%
y_train.shape
# Out:
# (214, 1)

# %%
x_test.shape
# Out:
# (853, 6)

# %%
y_test.shape
# Out:
# (853, 1)

# %%
sk_model = model.fit(x_train,y_train)
sk_model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
sk_model.coef_
# Out:
# array([[  7.09170082,   9.0375372 , -24.62809889, -11.95773755,
#          37.84719062,  -5.34710366]])

# %%
sk_model.intercept_
# Out:
# array([324.5626124])

# %%
sk_model.score(x_train,y_train)
# Out:
# 0.8989323303898548

# %%
sk_model.score(x_test,y_test)
# Out:
# 0.8814488955824513

# %%
new_predict = sk_model.predict(x_test)
new_predict.shape
# Out:
# (853, 1)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,new_predict)
# Out:
# 14.202147855393038

# %%
mean_squared_error(y_test,new_predict)
# Out:
# 466.5546855359404

# %%
r2_score(y_test,new_predict)
# Out:
# 0.8814488955824513

# %%
from sklearn.model_selection import cross_val_score

# %%
Cv_Result = cross_val_score(sk_model,x_train,y_train,cv=10)

# %%
Cv_Result
# Out:
# array([0.9165545 , 0.90849135, 0.89573945, 0.93495022, 0.92011355,
#        0.89675624, 0.95337332, 0.75141042, 0.82326303, 0.88634871])

# %%
np.mean(Cv_Result)
# Out:
# 0.8887000783512432

# %%
np.max(Cv_Result)
# Out:
# 0.9533733183187811

# %%
np.min(Cv_Result)
# Out:
# 0.7514104159697813

# %%
sk_model.predict([[2.0,4,9.9,6.7,8.5,53]])
# Out:
# array([[89.26576841]])

# %%
sk_model.predict([[2.0,4,9.9,6.7,8.5,33]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-76c959cca381> in <module>
# ----> 1 sk_model.predict([[2.0,4,9.9,6.7,8.5,33]])
#
# NameError: name 'sk_model' is not defined
